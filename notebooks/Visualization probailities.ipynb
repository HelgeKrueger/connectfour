# %% [markdown]
# # The usal imports

# %%
import sys
sys.path.append('..')

import random
import numpy as np
from time import time

from connectfour import ConnectFour
from agents.agent import Agent
from agents.tree_search_agent import TreeSearchAgent

from main import evaluate

# %% [markdown]
# # Creating a graphviz object

# %%
c = ConnectFour()
t = TreeSearchAgent(1)
t.move(c)
viz = t.visualize()
viz

# %% [markdown]
# Visualization in the other direction

# %%
viz.attr(rankdir='LR')
viz
